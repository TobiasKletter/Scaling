# %%
import pandas as pd
import os
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   after removing the cwd from sys.path.
# <style>.container { width:80% !important; }</style>

# %%
# Define location of output folders
out_dir = "/Volumes/TOB_WD2/Image_Analysis/Osmosis/DataFrames"

# %%
#2D ROI analysis (central slice)
input_folder_1 = "/Volumes/TOB_WD2/Microscopy/20230831_ODT_M_Osmosis_6633/Ctrl/2D_Intensity" + "/" 
input_folder_2 = "/Volumes/TOB_WD2/Microscopy/20230831_ODT_M_Osmosis_6633/Hypo_1/2D_Intensity" + "/"
input_folder_3 = "/Volumes/TOB_WD2/Microscopy/20230831_ODT_M_Osmosis_6633/Hypo_2/2D_Intensity" + "/" 
input_folder_4 = "/Volumes/TOB_WD2/Microscopy/20230901_ODT_M_Osmosis_6633/Ctrl/2D_Intensity" + "/"
input_folder_5 = "/Volumes/TOB_WD2/Microscopy/20230901_ODT_M_Osmosis_6633/Ctrl_2/2D_Intensity" + "/" 
input_folder_6 = "/Volumes/TOB_WD2/Microscopy/20230901_ODT_M_Osmosis_6633/Hypo_1/2D_Intensity" + "/"

input_folder_7 = "/Volumes/TOB_WD2/Microscopy/20230907_ODT_M_Osmosis_8020/Ctrl_1/2D_Intensity" + "/"
input_folder_8 = "/Volumes/TOB_WD2/Microscopy/20230907_ODT_M_Osmosis_8020/Hypo_1/2D_Intensity" + "/"
input_folder_9 = "/Volumes/TOB_WD2/Microscopy/20230908_ODT_M_Osmosis_8020/Ctrl_1/2D_Intensity" + "/"
input_folder_10 = "/Volumes/TOB_WD2/Microscopy/20230908_ODT_M_Osmosis_8020/Hypo_1/2D_Intensity" + "/"
input_folder_11 = "/Volumes/TOB_WD2/Microscopy/20230908_ODT_M_Osmosis_8020/Hypo_2ON/2D_Intensity" + "/"

input_folder_12 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Ctrl_1/2D_Intensity" + "/"
input_folder_13 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Ctrl_ON_long/2D_Intensity" + "/"
input_folder_14 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Ctrl_ON_Short/2D_Intensity" + "/"
input_folder_15 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Hypo_1/2D_Intensity" + "/"
input_folder_16 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Hypo_ON_long/2D_Intensity" + "/"
input_folder_17 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Hypo_ON_Short/2D_Intensity" + "/"

input_folder_18 = "/Volumes/TOB_WD2/Microscopy/20230919_ODT_M_Osmosis_7525/Ctrl_1/2D_Intensity" + "/"
input_folder_19 = "/Volumes/TOB_WD2/Microscopy/20230919_ODT_M_Osmosis_7525/Hypo_1/2D_Intensity" + "/"

input_folder_20 = "/Volumes/TOB_WD2/Microscopy/20230921_ODT_M_Osmosis_8020/Ctrl_1/2D_Intensity" + "/"
input_folder_21 = "/Volumes/TOB_WD2/Microscopy/20230921_ODT_M_Osmosis_8020/Hypo_1/2D_Intensity" + "/"

input_folder_22 = "/Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Ctrl_1/2D_Intensity" + "/"
input_folder_23 = "/Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Hypo_1/2D_Intensity" + "/"

input_folder_24 = "/Volumes/TOB_WD2/Microscopy/20230928_ODT_M_Osmosis_7525/Ctrl_1/2D_Intensity" + "/"
input_folder_25 = "/Volumes/TOB_WD2/Microscopy/20230928_ODT_M_Osmosis_7525/Hypo_1/2D_Intensity" + "/"

input_folder_26 = "/Volumes/TOB_WD2/Microscopy/20231013_ODT_M_Osmosis_7525/Ctrl_1/2D_Intensity" + "/"
input_folder_27 = "/Volumes/TOB_WD2/Microscopy/20231013_ODT_M_Osmosis_7525/Hypo_1/2D_Intensity" + "/"

#3D Analysis
input_table_3D_1 = "/Volumes/TOB_WD2/Microscopy/20230831_ODT_M_Osmosis_6633/Ctrl/3D_Intensity" + "/"
input_table_3D_2 = "/Volumes/TOB_WD2/Microscopy/20230831_ODT_M_Osmosis_6633/Hypo_1/3D_Intensity" + "/"
input_table_3D_3 = "/Volumes/TOB_WD2/Microscopy/20230831_ODT_M_Osmosis_6633/Hypo_2/3D_Intensity" + "/"
input_table_3D_4 = "/Volumes/TOB_WD2/Microscopy/20230901_ODT_M_Osmosis_6633/Ctrl/3D_Intensity" + "/"
input_table_3D_5 = "/Volumes/TOB_WD2/Microscopy/20230901_ODT_M_Osmosis_6633/Ctrl_2/3D_Intensity" + "/"
input_table_3D_6 = "/Volumes/TOB_WD2/Microscopy/20230901_ODT_M_Osmosis_6633/Hypo_1/3D_Intensity" + "/"

input_table_3D_7 = "/Volumes/TOB_WD2/Microscopy/20230907_ODT_M_Osmosis_8020/Ctrl_1/3D_Intensity" + "/"
input_table_3D_8 = "/Volumes/TOB_WD2/Microscopy/20230907_ODT_M_Osmosis_8020/Hypo_1/3D_Intensity" + "/"
input_table_3D_9 = "/Volumes/TOB_WD2/Microscopy/20230908_ODT_M_Osmosis_8020/Ctrl_1/3D_Intensity" + "/"
input_table_3D_10 = "/Volumes/TOB_WD2/Microscopy/20230908_ODT_M_Osmosis_8020/Hypo_1/3D_Intensity" + "/"
input_table_3D_11 = "/Volumes/TOB_WD2/Microscopy/20230908_ODT_M_Osmosis_8020/Hypo_2ON/3D_Intensity" + "/"

input_table_3D_12 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Ctrl_1/3D_Intensity" + "/"
input_table_3D_13 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Ctrl_ON_long/3D_Intensity" + "/"
input_table_3D_14 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Ctrl_ON_Short/3D_Intensity" + "/"
input_table_3D_15 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Hypo_1/3D_Intensity" + "/"
input_table_3D_16 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Hypo_ON_long/3D_Intensity" + "/"
input_table_3D_17 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Hypo_ON_Short/3D_Intensity" + "/"

input_table_3D_18 = "/Volumes/TOB_WD2/Microscopy/20230919_ODT_M_Osmosis_7525/Ctrl_1/3D_Intensity" + "/"
input_table_3D_19 = "/Volumes/TOB_WD2/Microscopy/20230919_ODT_M_Osmosis_7525/Hypo_1/3D_Intensity" + "/"

input_table_3D_20 = "/Volumes/TOB_WD2/Microscopy/20230921_ODT_M_Osmosis_8020/Ctrl_1/3D_Intensity" + "/"
input_table_3D_21 = "/Volumes/TOB_WD2/Microscopy/20230921_ODT_M_Osmosis_8020/Hypo_1/3D_Intensity" + "/"

input_table_3D_22 = "/Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Ctrl_1/3D_Intensity" + "/"
input_table_3D_23 = "/Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Hypo_1/3D_Intensity" + "/"

input_table_3D_24 = "/Volumes/TOB_WD2/Microscopy/20230928_ODT_M_Osmosis_7525/Ctrl_1/3D_Intensity" + "/"
input_table_3D_25 = "/Volumes/TOB_WD2/Microscopy/20230928_ODT_M_Osmosis_7525/Hypo_1/3D_Intensity" + "/"

input_table_3D_26 = "/Volumes/TOB_WD2/Microscopy/20231013_ODT_M_Osmosis_7525/Ctrl_1/3D_Intensity" + "/"
input_table_3D_27 = "/Volumes/TOB_WD2/Microscopy/20231013_ODT_M_Osmosis_7525/Hypo_1/3D_Intensity" + "/"

#Cell volumes
CV_folder_1 = "/Volumes/TOB_WD2/Microscopy/20230831_ODT_M_Osmosis_6633/Ctrl/Cell_Volumes" + "/"
CV_folder_2 = "/Volumes/TOB_WD2/Microscopy/20230831_ODT_M_Osmosis_6633/Hypo_1/Cell_Volumes" + "/"
CV_folder_3 = "/Volumes/TOB_WD2/Microscopy/20230831_ODT_M_Osmosis_6633/Hypo_2/Cell_Volumes" + "/"
CV_folder_4 = "/Volumes/TOB_WD2/Microscopy/20230901_ODT_M_Osmosis_6633/Ctrl/Cell_Volumes" + "/"
CV_folder_5 = "/Volumes/TOB_WD2/Microscopy/20230901_ODT_M_Osmosis_6633/Ctrl_2/Cell_Volumes" + "/"
CV_folder_6 = "/Volumes/TOB_WD2/Microscopy/20230901_ODT_M_Osmosis_6633/Hypo_1/Cell_Volumes" + "/"

CV_folder_7 = "/Volumes/TOB_WD2/Microscopy/20230907_ODT_M_Osmosis_8020/Ctrl_1/Cell_Volumes" + "/"
CV_folder_8 = "/Volumes/TOB_WD2/Microscopy/20230907_ODT_M_Osmosis_8020/Hypo_1/Cell_Volumes" + "/"
CV_folder_9 = "/Volumes/TOB_WD2/Microscopy/20230908_ODT_M_Osmosis_8020/Ctrl_1/Cell_Volumes" + "/"
CV_folder_10 = "/Volumes/TOB_WD2/Microscopy/20230908_ODT_M_Osmosis_8020/Hypo_1/Cell_Volumes" + "/"

CV_folder_11 = "/Volumes/TOB_WD2/Microscopy/20230908_ODT_M_Osmosis_8020/Hypo_2ON/Cell_Volumes" + "/"

CV_folder_12 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Ctrl_1/Cell_Volumes" + "/"
CV_folder_13 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Ctrl_ON_long/Cell_Volumes" + "/"
CV_folder_14 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Ctrl_ON_Short/Cell_Volumes" + "/"
CV_folder_15 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Hypo_1/Cell_Volumes" + "/"
CV_folder_16 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Hypo_ON_long/Cell_Volumes" + "/"
CV_folder_17 = "/Volumes/TOB_WD2/Microscopy/20230914_ODT_M_Osmosis_8020/Hypo_ON_Short/Cell_Volumes" + "/"

CV_folder_18 = "/Volumes/TOB_WD2/Microscopy/20230919_ODT_M_Osmosis_7525/Ctrl_1/Cell_Volumes" + "/"
CV_folder_19 = "/Volumes/TOB_WD2/Microscopy/20230919_ODT_M_Osmosis_7525/Hypo_1/Cell_Volumes" + "/"

CV_folder_20 = "/Volumes/TOB_WD2/Microscopy/20230921_ODT_M_Osmosis_8020/Ctrl_1/Cell_Volumes" + "/"
CV_folder_21 = "/Volumes/TOB_WD2/Microscopy/20230921_ODT_M_Osmosis_8020/Hypo_1/Cell_Volumes" + "/"

CV_folder_22 = "/Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Ctrl_1/Cell_Volumes" + "/"
CV_folder_23 = "/Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Hypo_1/Cell_Volumes" + "/"

CV_folder_24 = "/Volumes/TOB_WD2/Microscopy/20230928_ODT_M_Osmosis_7525/Ctrl_1/Cell_Volumes" + "/"
CV_folder_25 = "/Volumes/TOB_WD2/Microscopy/20230928_ODT_M_Osmosis_7525/Hypo_1/Cell_Volumes" + "/"

CV_folder_26 = "/Volumes/TOB_WD2/Microscopy/20231013_ODT_M_Osmosis_7525/Ctrl_1/Cell_Volumes" + "/"
CV_folder_27 = "/Volumes/TOB_WD2/Microscopy/20231013_ODT_M_Osmosis_7525/Hypo_1/Cell_Volumes" + "/"

def concat_ROI_measurements(folder, conditionstr, subconditionstr, datasetstr, RIMedium, DNA = False):
    dataframes = [] 
    dataframes_avg = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            filepath = root + os.sep + file 
            if not file.startswith("."):
                if filepath.endswith(".csv"):
                    single_df = pd.read_csv(filepath)
                    single_df["Condition"] = conditionstr
                    single_df["Subcondition"] = subconditionstr
                    single_df["Experiment"] = datasetstr
                    single_df["RI_of_medium"] = RIMedium
                    dataframes.append(single_df)
                    
                    cell_id = single_df.at[0, 'Label']
                    RI_average = single_df.Mean.mean()
                    
                    if not DNA == True:
                        dictionary = {
                            'Cell_ID': cell_id, 
                            'RI_average': RI_average, 
                            'Condition': conditionstr,
                            'Experiment': datasetstr,
                            'RI_of_medium': RIMedium,
                            'Subcondition': subconditionstr
                        }

                        avg_df = pd.DataFrame(dictionary, index = [0])
                        dataframes_avg.append(avg_df)
                    else:
                        dictionary = {
                            'Cell_ID': cell_id, 
                            'RI_average_DNA': RI_average, 
                            'Condition': conditionstr,
                            'Dataset': datasetstr
                        }

                        avg_df = pd.DataFrame(dictionary, index = [0])
                        dataframes_avg.append(avg_df)
                else:
                    pass
            else:
                pass
    df = pd.concat(dataframes)
    df_avg = pd.concat(dataframes_avg)
    return df, df_avg

df_D0_1, df_D0_avg_1 = concat_ROI_measurements(input_folder_1, conditionstr = "Control_6633", subconditionstr = "Ctrl_1", datasetstr = "20230831", RIMedium = 1.337)
df_D0_2, df_D0_avg_2 = concat_ROI_measurements(input_folder_2, conditionstr = "Hypo_6633", subconditionstr = "Hypo_1", datasetstr = "20230831", RIMedium = 1.336)
df_D0_3, df_D0_avg_3 = concat_ROI_measurements(input_folder_3, conditionstr = "Hypo_6633", subconditionstr = "Hypo_2", datasetstr = "20230831", RIMedium = 1.336)
df_D2_1, df_D2_avg_1 = concat_ROI_measurements(input_folder_4, conditionstr = "Control_6633", subconditionstr = "Ctrl_2", datasetstr = "20230901", RIMedium = 1.337)
df_D2_2, df_D2_avg_2 = concat_ROI_measurements(input_folder_5, conditionstr = "Control_6633", subconditionstr = "Ctrl_3", datasetstr = "20230901", RIMedium = 1.337)
df_D2_3, df_D2_avg_3 = concat_ROI_measurements(input_folder_6, conditionstr = "Hypo_6633", subconditionstr = "Hypo_3", datasetstr = "20230901", RIMedium = 1.336)

df_7, df_avg_7 = concat_ROI_measurements(input_folder_7, conditionstr = "Control_8020", subconditionstr = "Ctrl_4", datasetstr = "20230907", RIMedium = 1.337)
df_8, df_avg_8 = concat_ROI_measurements(input_folder_8, conditionstr = "Hypo_8020", subconditionstr = "Hypo_4", datasetstr = "20230907", RIMedium = 1.336)
df_9, df_avg_9 = concat_ROI_measurements(input_folder_9, conditionstr = "Control_8020", subconditionstr = "Ctrl_5", datasetstr = "20230908", RIMedium = 1.337)
df_10, df_avg_10 = concat_ROI_measurements(input_folder_10, conditionstr = "Hypo_8020", subconditionstr = "Hypo_5", datasetstr = "20230908", RIMedium = 1.336)
df_11, df_avg_11 = concat_ROI_measurements(input_folder_11, conditionstr = "Hypo_8020ON", subconditionstr = "Hypo_2ON", datasetstr = "20230908", RIMedium = 1.336)

df_12, df_avg_12 = concat_ROI_measurements(input_folder_12, conditionstr = "Control_8020", subconditionstr = "Ctrl_6", datasetstr = "20230914", RIMedium = 1.337)
df_13, df_avg_13 = concat_ROI_measurements(input_folder_13, conditionstr = "Control_8020ON_long", subconditionstr = "Ctrl_7ON", datasetstr = "20230914", RIMedium = 1.337)
df_14, df_avg_14 = concat_ROI_measurements(input_folder_14, conditionstr = "Control_8020ON_Short", subconditionstr = "Ctrl_8ON", datasetstr = "20230914", RIMedium = 1.337)
df_15, df_avg_15 = concat_ROI_measurements(input_folder_15, conditionstr = "Hypo_8020", subconditionstr = "Hypo_6", datasetstr = "20230914", RIMedium = 1.336)
df_16, df_avg_16 = concat_ROI_measurements(input_folder_16, conditionstr = "Hypo_8020ON_long", subconditionstr = "Hypo_7ON", datasetstr = "20230914", RIMedium = 1.336)
df_17, df_avg_17 = concat_ROI_measurements(input_folder_17, conditionstr = "Hypo_8020ON_Short", subconditionstr = "Hypo_8ON", datasetstr = "20230914", RIMedium = 1.336)

df_18, df_avg_18 = concat_ROI_measurements(input_folder_18, conditionstr = "Control_7525ON_Short", subconditionstr = "Ctrl_9ON", datasetstr = "20230919", RIMedium = 1.337)
df_19, df_avg_19 = concat_ROI_measurements(input_folder_19, conditionstr = "Hypo_7525ON_Short", subconditionstr = "Hypo_9ON", datasetstr = "20230919", RIMedium = 1.336)

df_20, df_avg_20 = concat_ROI_measurements(input_folder_20, conditionstr = "Control_8020ON_Short", subconditionstr = "Ctrl_10ON", datasetstr = "20230921", RIMedium = 1.337)
df_21, df_avg_21 = concat_ROI_measurements(input_folder_21, conditionstr = "Hypo_8020ON_Short", subconditionstr = "Hypo_10ON", datasetstr = "20230921", RIMedium = 1.336)

df_22, df_avg_22 = concat_ROI_measurements(input_folder_22, conditionstr = "Control_7525ON_Short", subconditionstr = "Ctrl_11ON", datasetstr = "20230926", RIMedium = 1.337)
df_23, df_avg_23 = concat_ROI_measurements(input_folder_23, conditionstr = "Hypo_7525ON_Short", subconditionstr = "Hypo_11ON", datasetstr = "20230926", RIMedium = 1.336)

df_24, df_avg_24 = concat_ROI_measurements(input_folder_24, conditionstr = "Control_7525ON_Short", subconditionstr = "Ctrl_12ON", datasetstr = "20230928", RIMedium = 1.337)
df_25, df_avg_25 = concat_ROI_measurements(input_folder_25, conditionstr = "Hypo_7525ON_Short", subconditionstr = "Hypo_12ON", datasetstr = "20230928", RIMedium = 1.336)

df_26, df_avg_26 = concat_ROI_measurements(input_folder_26, conditionstr = "Control_7525ON_Short", subconditionstr = "Ctrl_13ON", datasetstr = "20231013", RIMedium = 1.337)
df_27, df_avg_27 = concat_ROI_measurements(input_folder_27, conditionstr = "Hypo_7525ON_Short", subconditionstr = "Hypo_13ON", datasetstr = "20231013", RIMedium = 1.336)

print("Finished parsing data.")

df = pd.concat([
    df_D0_1, 
    df_D2_1, 
    df_D0_2, 
    df_D2_2, 
    df_D0_3, 
    df_D2_3, 
    df_7, 
    df_8, 
    df_9, 
    df_10, 
    df_11, 
    df_12, 
    df_13, 
    df_14, 
    df_15,
    df_16,
    df_17,
    df_18,
    df_19,
    df_20,
    df_21,
    df_22,
    df_23,
    df_24,
    df_25,
    df_26,
    df_27
])

df_avg = pd.concat([
    df_D0_avg_1, 
    df_D2_avg_1, 
    df_D0_avg_2, 
    df_D2_avg_2, 
    df_D0_avg_3, 
    df_D2_avg_3, 
    df_avg_7, 
    df_avg_8, 
    df_avg_9, 
    df_avg_10, 
    df_avg_11, 
    df_avg_12, 
    df_avg_13, 
    df_avg_14, 
    df_avg_15, 
    df_avg_16,
    df_avg_17,
    df_avg_18,
    df_avg_19,
    df_avg_20,
    df_avg_21,
    df_avg_22,
    df_avg_23,
    df_avg_24,
    df_avg_25,
    df_avg_26,
    df_avg_27
])

df_avg["Cell_ID"] = df_avg.Cell_ID.str.split(".").str.get(0)


df["Mass_density_cytop_mgml"] = (((df.Mean / 10000) - df.RI_of_medium) * 1000) / 0.19
df_avg["Mass_density_cytop_mgml"] = (((df_avg.RI_average / 10000) - df_avg.RI_of_medium) * 1000) / 0.19
#DNA_df_avg["Mass_density_DNA_mgml"] = (((DNA_df_avg.RI_average_DNA / 10000) - 1.337) * 1000) / 0.19

#df_avg = df_avg.merge(DNA_df_avg, how = "outer")

#df_avg["DNA_cytop_Density_Ratio"] = df_avg.Mass_density_DNA_mgml / df_avg.Mass_density_cytop_mgml

df_avg.head()
# Out:
# Finished parsing data.
#                 Cell_ID    RI_average     Condition Experiment  RI_of_medium  \
# 0  Tomogram_sample001-1  13638.400000  Control_6633  20230831   1.337
# 0  Tomogram_sample004-1  13653.341000  Control_6633  20230831   1.337
# 0  Tomogram_sample007-1  13637.197273  Control_6633  20230831   1.337
# 0  Tomogram_sample009-1  13634.800000  Control_6633  20230831   1.337
# 0  Tomogram_sample010-1  13644.550000  Control_6633  20230831   1.337
#
#   Subcondition  Mass_density_cytop_mgml
# 0  Ctrl_1       141.263158
# 0  Ctrl_1       149.126842
# 0  Ctrl_1       140.630144
# 0  Ctrl_1       139.368421
# 0  Ctrl_1       144.500000

# %%
# 3D measurements

def concat_misc_measurement(folder, conditionstring, subconditionstr, datasetstr, RIMedium):
    misc_dataframes = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            filepath = root + os.sep + file  
            if filepath.endswith(".csv"):
                single_df = pd.read_csv(filepath)
                single_df["Condition"] = conditionstring
                single_df["Experiment"] = datasetstr
                single_df["Subcondition"] = subconditionstr
                single_df["RI_of_medium"] = RIMedium
                misc_dataframes.append(single_df)    
            else:
                pass
    misc_df = pd.concat(misc_dataframes)
    return misc_df 

CV_df_D0_1 = concat_misc_measurement(CV_folder_1, conditionstring = "Control_6633", datasetstr = "20230831", RIMedium = 1.337, subconditionstr = "Ctrl_1")
CV_df_D2_1 = concat_misc_measurement(CV_folder_2, conditionstring = "Hypo_6633", datasetstr = "20230831", RIMedium = 1.336, subconditionstr = "Hypo_1")
CV_df_D0_2 = concat_misc_measurement(CV_folder_3, conditionstring = "Hypo_6633", datasetstr = "20230831", RIMedium = 1.336, subconditionstr = "Hypo_2")
CV_df_D2_2 = concat_misc_measurement(CV_folder_4, conditionstring = "Control_6633", datasetstr = "20230901", RIMedium = 1.337, subconditionstr = "Ctrl_2")
CV_df_D0_3 = concat_misc_measurement(CV_folder_5, conditionstring = "Control_6633", datasetstr = "20230901", RIMedium = 1.337, subconditionstr = "Ctrl_3")
CV_df_D2_3 = concat_misc_measurement(CV_folder_6, conditionstring = "Hypo_6633", datasetstr = "20230901", RIMedium = 1.336, subconditionstr = "Hypo_3")

CV_df_7 = concat_misc_measurement(CV_folder_7, conditionstring = "Control_8020", datasetstr = "20230907", RIMedium = 1.337, subconditionstr = "Ctrl_4")
CV_df_8 = concat_misc_measurement(CV_folder_8, conditionstring = "Hypo_8020", datasetstr = "20230907", RIMedium = 1.336, subconditionstr = "Hypo_4")
CV_df_9 = concat_misc_measurement(CV_folder_9, conditionstring = "Control_8020", datasetstr = "20230908", RIMedium = 1.337, subconditionstr = "Ctrl_5")
CV_df_10 = concat_misc_measurement(CV_folder_10, conditionstring = "Hypo_8020", datasetstr = "20230908", RIMedium = 1.336, subconditionstr = "Hypo_5")
CV_df_11 = concat_misc_measurement(CV_folder_11, conditionstring = "Hypo_8020ON", datasetstr = "20230908", RIMedium = 1.336, subconditionstr = "Hypo_2ON")

CV_df_12 = concat_misc_measurement(CV_folder_12, conditionstring = "Control_8020", datasetstr = "20230914", RIMedium = 1.337, subconditionstr = "Ctrl_6")
CV_df_13 = concat_misc_measurement(CV_folder_13, conditionstring = "Control_8020ON_long", datasetstr = "20230914", RIMedium = 1.337, subconditionstr = "Ctrl_7ON")
CV_df_14 = concat_misc_measurement(CV_folder_14, conditionstring = "Control_8020ON_Short", datasetstr = "20230914", RIMedium = 1.337, subconditionstr = "Ctrl_8ON")
CV_df_15 = concat_misc_measurement(CV_folder_15, conditionstring = "Hypo_8020", datasetstr = "20230914", RIMedium = 1.336, subconditionstr = "Hypo_6")
CV_df_16 = concat_misc_measurement(CV_folder_16, conditionstring = "Hypo_8020ON_long", datasetstr = "20230914", RIMedium = 1.336, subconditionstr = "Hypo_7ON")
CV_df_17 = concat_misc_measurement(CV_folder_17, conditionstring = "Hypo_8020ON_Short", datasetstr = "20230914", RIMedium = 1.336, subconditionstr = "Hypo_8ON")

CV_df_18 = concat_misc_measurement(CV_folder_18, conditionstring = "Control_7525ON_Short", datasetstr = "20230919", RIMedium = 1.337, subconditionstr = "Ctrl_9ON")
CV_df_19 = concat_misc_measurement(CV_folder_19, conditionstring = "Hypo_7525ON_Short", datasetstr = "20230919", RIMedium = 1.336, subconditionstr = "Hypo_9ON")

CV_df_20 = concat_misc_measurement(CV_folder_20, conditionstring = "Control_8020ON_Short", datasetstr = "20230921", RIMedium = 1.337, subconditionstr = "Ctrl_10ON")
CV_df_21 = concat_misc_measurement(CV_folder_21, conditionstring = "Hypo_8020ON_Short", datasetstr = "20230921", RIMedium = 1.336, subconditionstr = "Hypo_10ON")

CV_df_22 = concat_misc_measurement(CV_folder_22, conditionstring = "Control_7525ON_Short", datasetstr = "20230926", RIMedium = 1.337, subconditionstr = "Ctrl_11ON")
CV_df_23 = concat_misc_measurement(CV_folder_23, conditionstring = "Hypo_7525ON_Short", datasetstr = "20230926", RIMedium = 1.336, subconditionstr = "Hypo_11ON")

CV_df_24 = concat_misc_measurement(CV_folder_24, conditionstring = "Control_7525ON_Short", datasetstr = "20230928", RIMedium = 1.337, subconditionstr = "Ctrl_12ON")
CV_df_25 = concat_misc_measurement(CV_folder_25, conditionstring = "Hypo_7525ON_Short", datasetstr = "20230928", RIMedium = 1.336, subconditionstr = "Hypo_12ON")

CV_df_26 = concat_misc_measurement(CV_folder_26, conditionstring = "Control_7525ON_Short", datasetstr = "20231013", RIMedium = 1.337, subconditionstr = "Ctrl_13ON")
CV_df_27 = concat_misc_measurement(CV_folder_27, conditionstring = "Hypo_7525ON_Short", datasetstr = "20231013", RIMedium = 1.336, subconditionstr = "Hypo_13ON")

Intensity_df_D0_1 = concat_misc_measurement(input_table_3D_1, conditionstring = "Control_6633", datasetstr = "20230831", RIMedium = 1.337, subconditionstr = "Ctrl_1")
Intensity_df_D2_1 = concat_misc_measurement(input_table_3D_2, conditionstring = "Hypo_6633", datasetstr = "20230831", RIMedium = 1.336, subconditionstr = "Hypo_1")
Intensity_df_D0_2 = concat_misc_measurement(input_table_3D_3, conditionstring = "Hypo_6633", datasetstr = "20230831", RIMedium = 1.336, subconditionstr = "Hypo_2")
Intensity_df_D2_2 = concat_misc_measurement(input_table_3D_4, conditionstring = "Control_6633", datasetstr = "20230901", RIMedium = 1.337, subconditionstr = "Ctrl_2")
Intensity_df_D0_3 = concat_misc_measurement(input_table_3D_5, conditionstring = "Control_6633", datasetstr = "20230901", RIMedium = 1.337, subconditionstr = "Ctrl_3")
Intensity_df_D2_3 = concat_misc_measurement(input_table_3D_6, conditionstring = "Hypo_6633", datasetstr = "20230901", RIMedium = 1.336, subconditionstr = "Hypo_3")

Intensity_df_7 = concat_misc_measurement(input_table_3D_7, conditionstring = "Control_8020", datasetstr = "20230907", RIMedium = 1.337, subconditionstr = "Ctrl_4")
Intensity_df_8 = concat_misc_measurement(input_table_3D_8, conditionstring = "Hypo_8020", datasetstr = "20230907", RIMedium = 1.336, subconditionstr = "Hypo_4")
Intensity_df_9 = concat_misc_measurement(input_table_3D_9, conditionstring = "Control_8020", datasetstr = "20230908", RIMedium = 1.337, subconditionstr = "Ctrl_5")
Intensity_df_10 = concat_misc_measurement(input_table_3D_10, conditionstring = "Hypo_8020", datasetstr = "20230908", RIMedium = 1.336, subconditionstr = "Hypo_5")
Intensity_df_11 = concat_misc_measurement(input_table_3D_11, conditionstring = "Hypo_8020ON", datasetstr = "20230908", RIMedium = 1.336, subconditionstr = "Hypo_2ON")

Intensity_df_12 = concat_misc_measurement(input_table_3D_12, conditionstring = "Control_8020", datasetstr = "20230914", RIMedium = 1.337, subconditionstr = "Ctrl_6")
Intensity_df_13 = concat_misc_measurement(input_table_3D_13, conditionstring = "Control_8020ON_long", datasetstr = "20230914", RIMedium = 1.337, subconditionstr = "Ctrl_7ON")
Intensity_df_14 = concat_misc_measurement(input_table_3D_14, conditionstring = "Control_8020ON_Short", datasetstr = "20230914", RIMedium = 1.337, subconditionstr = "Ctrl_8ON")
Intensity_df_15 = concat_misc_measurement(input_table_3D_15, conditionstring = "Hypo_8020", datasetstr = "20230914", RIMedium = 1.336, subconditionstr = "Hypo_6")
Intensity_df_16 = concat_misc_measurement(input_table_3D_16, conditionstring = "Hypo_8020ON_long", datasetstr = "20230914", RIMedium = 1.336, subconditionstr = "Hypo_7ON")
Intensity_df_17 = concat_misc_measurement(input_table_3D_17, conditionstring = "Hypo_8020ON_Short", datasetstr = "20230914", RIMedium = 1.336, subconditionstr = "Hypo_8ON")

Intensity_df_18 = concat_misc_measurement(input_table_3D_18, conditionstring = "Control_7525ON_Short", datasetstr = "20230919", RIMedium = 1.337, subconditionstr = "Ctrl_9ON")
Intensity_df_19 = concat_misc_measurement(input_table_3D_19, conditionstring = "Hypo_7525ON_Short", datasetstr = "20230919", RIMedium = 1.336, subconditionstr = "Hypo_9ON")
Intensity_df_20 = concat_misc_measurement(input_table_3D_20, conditionstring = "Control_8020ON_Short", datasetstr = "20230921", RIMedium = 1.337, subconditionstr = "Ctrl_10ON")
Intensity_df_21 = concat_misc_measurement(input_table_3D_21, conditionstring = "Hypo_8020ON_Short", datasetstr = "20230921", RIMedium = 1.336, subconditionstr = "Hypo_10ON")

Intensity_df_22 = concat_misc_measurement(input_table_3D_22, conditionstring = "Control_7525ON_Short", datasetstr = "20230926", RIMedium = 1.337, subconditionstr = "Ctrl_11ON")
Intensity_df_23 = concat_misc_measurement(input_table_3D_23, conditionstring = "Hypo_7525ON_Short", datasetstr = "20230926", RIMedium = 1.336, subconditionstr = "Hypo_11ON")

Intensity_df_24 = concat_misc_measurement(input_table_3D_24, conditionstring = "Control_7525ON_Short", datasetstr = "20230928", RIMedium = 1.337, subconditionstr = "Ctrl_12ON")
Intensity_df_25 = concat_misc_measurement(input_table_3D_25, conditionstring = "Hypo_7525ON_Short", datasetstr = "20230928", RIMedium = 1.336, subconditionstr = "Hypo_12ON")

Intensity_df_26 = concat_misc_measurement(input_table_3D_26, conditionstring = "Control_7525ON_Short", datasetstr = "20231013", RIMedium = 1.337, subconditionstr = "Ctrl_13ON")
Intensity_df_27 = concat_misc_measurement(input_table_3D_27, conditionstring = "Hypo_7525ON_Short", datasetstr = "20231013", RIMedium = 1.336, subconditionstr = "Hypo_13ON")

CV_df = pd.concat([
    CV_df_D0_1, 
    CV_df_D2_1, 
    CV_df_D0_2, 
    CV_df_D2_2, 
    CV_df_D0_3, 
    CV_df_D2_3, 
    CV_df_7, 
    CV_df_8, 
    CV_df_9, 
    CV_df_10, 
    CV_df_11, 
    CV_df_12, 
    CV_df_13, 
    CV_df_14, 
    CV_df_15, 
    CV_df_16,
    CV_df_17, 
    CV_df_18,
    CV_df_19,
    CV_df_20,
    CV_df_21,
    CV_df_22,
    CV_df_23,
    CV_df_24,
    CV_df_25,
    CV_df_26,
    CV_df_27
])

Intensity_df = pd.concat([
    Intensity_df_D0_1, 
    Intensity_df_D2_1, 
    Intensity_df_D0_2, 
    Intensity_df_D2_2, 
    Intensity_df_D0_3, 
    Intensity_df_D2_3, 
    Intensity_df_7, 
    Intensity_df_8, 
    Intensity_df_9, 
    Intensity_df_10, 
    Intensity_df_11, 
    Intensity_df_12, 
    Intensity_df_13, 
    Intensity_df_14, 
    Intensity_df_15, 
    Intensity_df_16,
    Intensity_df_17, 
    Intensity_df_18,
    Intensity_df_19, 
    Intensity_df_20,
    Intensity_df_21, 
    Intensity_df_22,
    Intensity_df_23, 
    Intensity_df_24,
    Intensity_df_25, 
    Intensity_df_26,
    Intensity_df_27
    
])
Intensity_df["Cell mass density (mg/ml)"] = (((Intensity_df.Average / 10000) - Intensity_df.RI_of_medium) * 1000) / 0.19
CV_df.head()
# Out:
#       Label    Volume  SurfaceArea  Sphericity               Cell_ID  \
# 0  1  65535  1637.628  699.756      0.885       Tomogram_sample001-1
# 0  1  65535  1797.086  724.882      0.959       Tomogram_sample004-1
# 0  1  65535  2542.591  926.978      0.918       Tomogram_sample007-1
# 0  1  65535  1926.461  804.455      0.806       Tomogram_sample009-1
# 0  1  65535  2459.995  889.059      0.974       Tomogram_sample010-1
#
#       Condition Experiment Subcondition  RI_of_medium
# 0  Control_6633  20230831   Ctrl_1       1.337
# 0  Control_6633  20230831   Ctrl_1       1.337
# 0  Control_6633  20230831   Ctrl_1       1.337
# 0  Control_6633  20230831   Ctrl_1       1.337
# 0  Control_6633  20230831   Ctrl_1       1.337

# %%
# parse Spindle Areas

spindle_dir_1 = "/Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Ctrl_1/Spindle_Areas"
spindle_dir_2 = "/Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Hypo_1/Spindle_Areas"

spindle_dir_3 = "/Volumes/TOB_WD2/Microscopy/20230928_ODT_M_Osmosis_7525/Ctrl_1/Spindle_Areas"
spindle_dir_4 = "/Volumes/TOB_WD2/Microscopy/20230928_ODT_M_Osmosis_7525/Hypo_1/Spindle_Areas"

spindle_dir_5 = "/Volumes/TOB_WD2/Microscopy/20231013_ODT_M_Osmosis_7525/Ctrl_1/Spindle_Areas"
spindle_dir_6 = "/Volumes/TOB_WD2/Microscopy/20231013_ODT_M_Osmosis_7525/Hypo_1/Spindle_Areas"

def concat_spindle_area(folder, conditionstring, datasetstr):
    misc_dataframes = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if not file.startswith("."):
                filepath = root + os.sep + file
                cell_id = file
                if filepath.endswith(".csv"):
                    print(filepath)
                    single_df = pd.read_csv(filepath)
                    single_df["Condition"] = conditionstring
                    single_df["Experiment"] = datasetstr
                    single_df["Cell_ID"] = cell_id
                    misc_dataframes.append(single_df)    
                else:
                    pass
            else:
                pass
    misc_df = pd.concat(misc_dataframes)
    return misc_df

def cell_ids(x):
    epi_ID_main = x.split("_")[1].split("_")[0].zfill(3)
    epi_ID_sub = x.split("-")[1].split("_")[0]
    new_ID = "Tomogram_sample" + epi_ID_main + "-" + epi_ID_sub
    return new_ID

spindle_df_1 = concat_spindle_area(spindle_dir_1, conditionstring = "Control_7525ON_Short", datasetstr = "20230926")
spindle_df_2 = concat_spindle_area(spindle_dir_2, conditionstring = "Hypo_7525ON_Short", datasetstr = "20230926")
spindle_df_3 = concat_spindle_area(spindle_dir_3, conditionstring = "Control_7525ON_Short", datasetstr = "20230928")
spindle_df_4 = concat_spindle_area(spindle_dir_4, conditionstring = "Hypo_7525ON_Short", datasetstr = "20230928")
spindle_df_5 = concat_spindle_area(spindle_dir_5, conditionstring = "Control_7525ON_Short", datasetstr = "20231013")
spindle_df_6 = concat_spindle_area(spindle_dir_6, conditionstring = "Hypo_7525ON_Short", datasetstr = "20231013")

spindle_df = pd.concat([
    spindle_df_1, 
    spindle_df_2, 
    spindle_df_3, 
    spindle_df_4, 
    spindle_df_5, 
    spindle_df_6
])
spindle_df["Cell_ID"] = spindle_df.Cell_ID.apply(cell_ids)
spindle_df.head()
# Out:
# /Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Ctrl_1/Spindle_Areas/Sample_10_MMStack_Default.ome-1_SpindleArea.csv
# /Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Ctrl_1/Spindle_Areas/Sample_11_MMStack_Default.ome-1_SpindleArea.csv
# /Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Ctrl_1/Spindle_Areas/Sample_12_MMStack_Default.ome-1_SpindleArea.csv
# /Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Ctrl_1/Spindle_Areas/Sample_13_MMStack_Default.ome-1_SpindleArea.csv
# /Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Ctrl_1/Spindle_Areas/Sample_14_MMStack_Default.ome-1_SpindleArea.csv
# /Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Ctrl_1/Spindle_Areas/Sample_15_MMStack_Default.ome-1_SpindleArea.csv
# /Volumes/TOB_WD2/Microscopy/20230926_ODT_M_Osmosis_7525/Ctrl_1/Spindle_Areas/Sample_16_MMStack_Default.ome-1_SpindleArea.csv
# ...

# %%
df_all = df_avg.merge(CV_df, on = ["Cell_ID", "Condition", "Subcondition", "Experiment"], how = "inner")

df_all = df_all.merge(Intensity_df, on = ["Cell_ID", "Condition", "Subcondition", "Experiment"], how = "inner")

df_all = df_all.merge(spindle_df, on = ["Cell_ID", "Condition", "Experiment"], how = "outer")

df_all["Dry_mass"] = df_all["Cell mass density (mg/ml)"] * df_all.Volume * 10**-3 #picogram

df_all["Spindle_occupancy"] = df_all.Area / df_all.Volume
df_all["SpindleArea_DryMass_Ratio"] = df_all.Area / df_all.Dry_mass

df_all.head()
# Out:
#                 Cell_ID    RI_average     Condition Experiment  \
# 0  Tomogram_sample001-1  13638.400000  Control_6633  20230831
# 1  Tomogram_sample004-1  13653.341000  Control_6633  20230831
# 2  Tomogram_sample007-1  13637.197273  Control_6633  20230831
# 3  Tomogram_sample009-1  13634.800000  Control_6633  20230831
# 4  Tomogram_sample010-1  13644.550000  Control_6633  20230831
#
#    RI_of_medium_x Subcondition  Mass_density_cytop_mgml   _x  Label_x  \
# 0  1.337           Ctrl_1       141.263158               1.0  65535.0
# 1  1.337           Ctrl_1       149.126842               1.0  65535.0
# 2  1.337           Ctrl_1       140.630144               1.0  65535.0
# 3  1.337           Ctrl_1       139.368421               1.0  65535.0
# 4  1.337           Ctrl_1       144.500000               1.0  65535.0
#
#      Volume  ...  IntegratedDensity  Channel  Frame  RI_of_medium  \
# 0  1637.628  ...  1.622799e+09       1.0      1.0    1.337
# ...

# %%
final_out = out_dir + "/" + "MasterDataFrame_Osmosis_Mitosis.csv"
df_all.to_csv(final_out)
print("Successfully saved dataframe to {}".format(final_out))
# Out:
# Successfully saved dataframe to /Volumes/TOB_WD2/Image_Analysis/Osmosis/DataFrames/MasterDataFrame_Osmosis_Mitosis.csv
